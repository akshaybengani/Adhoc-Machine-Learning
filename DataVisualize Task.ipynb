# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('datavis1data.csv')
df
# Out:
#      student_name  marks  age     contact  study_hours
# 0  Akshay Bengani    100   21  7737929302            5
# 1  Piyush Agarwal     50   20  7844246982            1
# 2     Priyal Vyas     90   19  9632587410            3
# 3   Abhinay Bhatt     70   22  1478963250            8

# %%
plt.pie(df.age,labels=df.student_name,shadow=True)
plt.show()

# %%
plt.pie(df.marks,labels=df.student_name,shadow=True)
plt.show()

# %%
plt.pie(df.study_hours,labels=df.student_name,shadow=True)
plt.show()
